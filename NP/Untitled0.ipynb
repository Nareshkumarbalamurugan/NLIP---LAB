# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.15.1-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from SpeechRecognition) (4.15.0)
# Downloading speechrecognition-3.15.1-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 51.8 MB/s eta 0:00:00
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.15.1

# %%
# !pip install pipwin
# !pipwin install pyaudio
# Out:
# Requirement already satisfied: pipwin in /usr/local/lib/python3.12/dist-packages (0.5.2)
# Requirement already satisfied: docopt in /usr/local/lib/python3.12/dist-packages (from pipwin) (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pipwin) (2.32.4)
# Requirement already satisfied: pyprind in /usr/local/lib/python3.12/dist-packages (from pipwin) (2.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from pipwin) (1.17.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from pipwin) (4.13.5)
# Requirement already satisfied: js2py in /usr/local/lib/python3.12/dist-packages (from pipwin) (0.74)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pipwin) (26.0)
# Requirement already satisfied: pySmartDL>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pipwin) (1.3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9.0->pipwin) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9.0->pipwin) (4.15.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.12/dist-packages (from js2py->pipwin) (5.3.1)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from js2py->pipwin) (2.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pipwin) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pipwin) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pipwin) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pipwin) (2026.2.25)
# Traceback (most recent call last):
#   File "/usr/local/bin/pipwin", line 5, in <module>
#     from pipwin.command import main
#   File "/usr/local/lib/python3.12/dist-packages/pipwin/command.py", line 28, in <module>
#     from . import pipwin, __version__
#   File "/usr/local/lib/python3.12/dist-packages/pipwin/pipwin.py", line 13, in <module>
#     import js2py
#   File "/usr/local/lib/python3.12/dist-packages/js2py/__init__.py", line 72, in <module>
#     from .base import PyJsException
#   File "/usr/local/lib/python3.12/dist-packages/js2py/base.py", line 2965, in <module>
#     @Js
#      ^^
#   File "/usr/local/lib/python3.12/dist-packages/js2py/base.py", line 165, in Js
#     return PyJsFunction(val, FunctionPrototype)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/js2py/base.py", line 1377, in __init__
#     cand = fix_js_args(func)
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/js2py/utils/injector.py", line 27, in fix_js_args
#     code = append_arguments(six.get_function_code(func), ('this', 'arguments'))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/js2py/utils/injector.py", line 121, in append_arguments
#     arg = name_translations[inst.arg]
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
# KeyError: 3

# %%
#pip install SpeechRecognition
#pip install gTTS
#pip install pyaudio
import speech_recognition as sr
from gtts import gTTS
import os
import platform

r = sr.Recognizer()

with sr.Microphone() as source:
    print("Speak something...")
    audio = r.listen(source)

text = r.recognize_google(audio)

print("Recognized Text:", text)

# Convert text to speech
tts = gTTS(text=text, lang="en")
tts.save("output.mp3")

# Detect OS and play audio
system = platform.system()

if system == "Windows":
    os.system("start output.mp3")
elif system == "Linux":
    os.system("xdg-open output.mp3")
else:
    print("Audio saved as output.mp3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     104         try:
# --> 105             import pyaudio
#     106         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_217/1362197719.py in <cell line: 0>()
#       9 r = sr.Recognizer()
#      10
# ---> 11 with sr.Microphone() as source:
#      12     print("Speak something...")
#      13     audio = r.listen(source)
#
# /usr/local/lib/python3.12/dist-packages/speech_recognition/__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      75
#      76         # set up PyAudio
# ---> 77         self.pyaudio_module = self.get_pyaudio()
#      78         audio = self.pyaudio_module.PyAudio()
#      79         try:
#
# /usr/local/lib/python3.12/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     105             import pyaudio
#     106         except ImportError:
# --> 107             raise AttributeError("Could not find PyAudio; check installation")
#     108         return pyaudio
#     109
#
# AttributeError: Could not find PyAudio; check installation
